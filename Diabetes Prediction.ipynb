# %%
import numpy as py

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes=pd.read_csv('diabetes.csv')

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
diabetes.set_index('Outcome',inplace=True)

# %%
diabetes
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Outcome
# 1                  6      148             72             35        0  33.6
# 0                  1       85             66             29        0  26.6
# 1                  8      183             64              0        0  23.3
# 0                  1       89             66             23       94  28.1
# 1                  0      137             40             35      168  43.1
# ...              ...      ...            ...            ...      ...   ...
# 0                 10      101             76             48      180  32.9
# 0                  2      122             70             27        0  36.8
# 0                  5      121             72             23      112  26.2
# 1                  1      126             60              0        0  30.1
# 0                  1       93             70             31        0  30.4
#
#          DiabetesPedigreeFunction  Age
# Outcome
# ...

# %%
import matplotlib

# %%
plt.figure(figsize=(10,6))
plt.title("Relation between pregnancies and Diabetes")
sns.barplot(x='Pregnancies',y='Outcome',data=diabetes,palette='inferno')
plt.show()

# %%
plt.title("Relation between Glucose and Diabetes")
plt.hist(diabetes.Glucose)
# Out:
# (array([  5.,   0.,   4.,  32., 156., 211., 163.,  95.,  56.,  46.]),
#  array([  0. ,  19.9,  39.8,  59.7,  79.6,  99.5, 119.4, 139.3, 159.2,
#         179.1, 199. ]),
#  <BarContainer object of 10 artists>)

# %%
diabetes.BloodPressure.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
diabetes.BMI.plot()
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10,6))
plt.title("Relation between pregnencies and Diabetes")
sns.barplot(x='Insulin',y='Outcome',data=diabetes)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title("Relation between Age and Diabetes")
sns.barplot(x='Age',y='Outcome',data=diabetes)
plt.show()

# %%
Nodib=diabetes[diabetes.Outcome==1]

# %%
Nodib
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
corr_mat_diabetes=diabetes.corr().round(3)
corr_mat_diabetes
# Out:
#                           Pregnancies  Glucose  BloodPressure  SkinThickness  \
# Pregnancies                     1.000    0.129          0.141         -0.082
# Glucose                         0.129    1.000          0.153          0.057
# BloodPressure                   0.141    0.153          1.000          0.207
# SkinThickness                  -0.082    0.057          0.207          1.000
# Insulin                        -0.074    0.331          0.089          0.437
# BMI                             0.018    0.221          0.282          0.393
# DiabetesPedigreeFunction       -0.034    0.137          0.041          0.184
# Age                             0.544    0.264          0.240         -0.114
# Outcome                         0.222    0.467          0.065          0.075
#
#                           Insulin    BMI  DiabetesPedigreeFunction    Age  \
# Pregnancies                -0.074  0.018                    -0.034  0.544
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(diabetes.corr().round(3),annot=True)
plt.title('Representation in matrix form')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
